# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import Lasso, LassoCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import PolynomialFeatures
from sklearn.utils import shuffle
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

# %%
# %matplotlib inline

# %%
# Read in data
X_train = pd.read_csv("../data/scaled_X_train.csv")
y_train = pd.read_csv("../data/scaled_y_train.csv")
X_test = pd.read_csv("../data/scaled_X_test.csv")
y_test = pd.read_csv("../data/scaled_y_test.csv")
# Out:
#     year  democrat_perc  AvgSalary  PerCapNetEarning  PerCapNetIncome  \
# 0   -1.0       1.187014   1.023277          0.984646         0.850506
# 1   -1.0       1.199637   0.023937         -0.383640        -0.462143
# 2   -1.0      -0.572699  -1.057257         -1.294860        -1.396147
# 3   -1.0       0.833619   0.072848          0.041553        -0.012319
# 4   -1.0       0.756480  -0.606384         -0.832131        -0.890741
# ..   ...            ...        ...               ...              ...
# 81  -1.0       0.268648  -0.536786         -1.097796        -0.635107
# 82   1.0       1.113258   2.182952          2.331576         2.469800
# 83  -1.0       1.197647   0.451310          0.861522         0.558754
# 84   1.0      -1.377571  -0.664514          0.222276         0.476201
# 85   1.0      -1.035567  -0.642589         -0.530063        -0.074938
#
#     TotalNumJobs  Sale_Prices  MedianListingPricePerSqft_1Bedroom  \
# 0       0.178410     1.221901                           -0.004104
# 1      -0.750147    -0.009682                            0.026937
# 2      -0.280227    -1.590602                           -0.473441
# 3       0.112448     0.760825                           -0.216729
# 4      -0.309058     0.428678                           -0.623486
# ..           ...          ...                                 ...
# 81      1.709790    -0.487949                           -0.487212
# 82      0.303432     1.831221                            1.609047
# 83     -0.020110     0.690988                            0.026746
# 84     -0.736866     0.334509                            0.026937
# 85     -0.719057     0.434101                            0.424615
#
#     MedianListingPricePerSqft_2Bedroom  MedianListingPricePerSqft_3Bedroom  \
# 0                            -0.036893                            0.021631
# 1                             0.080594                            0.070108
# 2                            -0.440902                           -0.402933
# 3                            -0.353839                           -0.324579
# 4                            -0.444504                           -0.301532
# ..                                 ...                                 ...
# 81                           -0.597988                           -0.678061
# 82                            1.034136                            1.190314
# 83                            0.092716                            0.119988
# 84                            0.080594                            0.070108
# 85                            0.267561                            0.288957
#
#     MedianListingPricePerSqft_4Bedroom  \
# 0                             0.023977
# 1                            -0.025834
# 2                            -0.376713
# 3                            -0.287681
# 4                            -0.277814
# ..                                 ...
# 81                           -0.592422
# 82                            1.152527
# 83                            0.050119
# 84                           -0.025834
# 85                            0.344213
#
#     MedianListingPricePerSqft_5BedroomOrMore
# 0                                  -0.025684
# 1                                  -0.083322
# 2                                  -0.337893
# 3                                  -0.215065
# 4                                  -0.221680
# ..                                       ...
# 81                                 -0.530056
# 82                                  0.544130
# 83                                  0.038362
# 84                                 -0.083322
# 85                                  0.357184
#
# [86 rows x 12 columns]
