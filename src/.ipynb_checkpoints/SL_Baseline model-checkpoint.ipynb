# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import Lasso, LassoCV
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import PolynomialFeatures
from sklearn.utils import shuffle

# %%
# %matplotlib inline

# %%
ecopolitics = pd.read_csv("../data/homeless_count_Econ_Politics_by_state.csv")
ecopolitics.rename(columns={"state_abbrev": "state"},inplace=True)
ecopolitics
# Out:
#      year state  homeless_count   win_party  AvgSalary  PerCapNetEarning  \
# 0    2008    AK          7462.0  Republican    48527.0           31586.0
# 1    2008    AL         23652.0  Republican    38138.0           20229.0
# 2    2008    AR         14806.0  Republican    35310.0           18526.0
# 3    2008    AZ         56146.0  Republican    43311.0           22318.0
# 4    2008    CA        626632.0    Democrat    52524.0           28770.0
# ..    ...   ...             ...         ...        ...               ...
# 103  2016    VT          5762.0    Democrat    44188.0           29569.0
# 104  2016    WA        103862.0  Republican    58989.0           34596.0
# 105  2016    WI         27656.0  Republican    46551.0           30320.0
# 106  2016    WV          7020.0  Republican    41183.0           20587.0
# 107  2016    WY          4184.0  Republican    46028.0           30753.0
#
#      PerCapNetIncome  TotalNumJobs
# 0            47749.0      443538.0
# ...

# %%
housingprice = pd.read_csv("../data/homeless_count_with_housing_price_by_state.csv")
housingprice.rename(columns={"Year_only": "year"},inplace=True)
housingprice
# Out:
#      year state_abbrev  homeless_count    Sale_Prices  \
# 0    2008           AK            7462            NaN
# 1    2008           AL           23652            NaN
# 2    2008           AR           14806            NaN
# 3    2008           AZ           56146  190750.000000
# 4    2008           CA          626632  314980.000000
# ..    ...          ...             ...            ...
# 103  2016           VT            5762            NaN
# 104  2016           WA          103862  294916.666667
# 105  2016           WI           27656  163283.333333
# 106  2016           WV            7020  140341.666667
# 107  2016           WY            4184  227700.000000
#
#      MedianListingPricePerSqft_1Bedroom  MedianListingPricePerSqft_2Bedroom  \
# 0                                   NaN                                 NaN
# 1                                   NaN                                 NaN
# 2                                   NaN                                 NaN
# ...

# %% [markdown]
# ## Combine two dataframe

# %%
combined = pd.concat([ecopolitics, housingprice.drop(columns=['year', 'state_abbrev','homeless_count'])], axis=1, join="inner")
combined
# Out:
#      year state  homeless_count   win_party  AvgSalary  PerCapNetEarning  \
# 0    2008    AK          7462.0  Republican    48527.0           31586.0
# 1    2008    AL         23652.0  Republican    38138.0           20229.0
# 2    2008    AR         14806.0  Republican    35310.0           18526.0
# 3    2008    AZ         56146.0  Republican    43311.0           22318.0
# 4    2008    CA        626632.0    Democrat    52524.0           28770.0
# ..    ...   ...             ...         ...        ...               ...
# 103  2016    VT          5762.0    Democrat    44188.0           29569.0
# 104  2016    WA        103862.0  Republican    58989.0           34596.0
# 105  2016    WI         27656.0  Republican    46551.0           30320.0
# 106  2016    WV          7020.0  Republican    41183.0           20587.0
# 107  2016    WY          4184.0  Republican    46028.0           30753.0
#
#      PerCapNetIncome  TotalNumJobs    Sale_Prices  \
# ...

# %% [markdown]
# ## EDA

# %%
sns.pairplot(combined,y_vars=['homeless_count'])

# %% [markdown]
# ## Preprocess data

# %%
# Categorical variables: state_abbrev (use one-hot encoding later)
enc = OrdinalEncoder()
# enc = OneHotEncoder(handle_unknown='ignore')
combined['state'] = enc.fit_transform(combined[['state']])

# Categorical variables: win_party
combined['win_party'] = [1 if i == 'Democrat' else 0 for i in combined['win_party']]

combined
# Out:
#      year  state  homeless_count  win_party  AvgSalary  PerCapNetEarning  \
# 0    2008    0.0          7462.0          0    48527.0           31586.0
# 1    2008    1.0         23652.0          0    38138.0           20229.0
# 2    2008    2.0         14806.0          0    35310.0           18526.0
# 3    2008    3.0         56146.0          0    43311.0           22318.0
# 4    2008    4.0        626632.0          1    52524.0           28770.0
# ..    ...    ...             ...        ...        ...               ...
# 103  2016   49.0          5762.0          1    44188.0           29569.0
# 104  2016   50.0        103862.0          0    58989.0           34596.0
# 105  2016   51.0         27656.0          0    46551.0           30320.0
# 106  2016   52.0          7020.0          0    41183.0           20587.0
# 107  2016   53.0          4184.0          0    46028.0           30753.0
#
#      PerCapNetIncome  TotalNumJobs    Sale_Prices  \
# ...

# %%
# kNN imputer
knn_imp = KNNImputer(n_neighbors=5)
imputed = pd.DataFrame(knn_imp.fit_transform(combined))
imputed.columns = combined.columns
imputed
# Out:
#        year  state  homeless_count  win_party  AvgSalary  PerCapNetEarning  \
# 0    2008.0    0.0          7462.0        0.0    48527.0           31586.0
# 1    2008.0    1.0         23652.0        0.0    38138.0           20229.0
# 2    2008.0    2.0         14806.0        0.0    35310.0           18526.0
# 3    2008.0    3.0         56146.0        0.0    43311.0           22318.0
# 4    2008.0    4.0        626632.0        1.0    52524.0           28770.0
# ..      ...    ...             ...        ...        ...               ...
# 103  2016.0   49.0          5762.0        1.0    44188.0           29569.0
# 104  2016.0   50.0        103862.0        0.0    58989.0           34596.0
# 105  2016.0   51.0         27656.0        0.0    46551.0           30320.0
# 106  2016.0   52.0          7020.0        0.0    41183.0           20587.0
# 107  2016.0   53.0          4184.0        0.0    46028.0           30753.0
#
#      PerCapNetIncome  TotalNumJobs    Sale_Prices  \
# ...

# %% [markdown]
# ## Baseline model

# %%
X = imputed.drop(columns='homeless_count')
y = imputed['homeless_count']

# Shuffle

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
baseline_linreg = LinearRegression().fit(X_train, y_train)

# %%
#Predict
y_pred_train = baseline_linreg.predict(X_train)
y_pred_test = baseline_linreg.predict(X_test)

#Compute the MSE of the model
train_mse = mean_squared_error(y_train,y_pred_train)
test_mse = mean_squared_error(y_test,y_pred_test)

print('train_mse: ' + str(train_mse))
print('test_mse: ' + str(test_mse))
# Out:
# train_mse: 1071725590.7248532
# test_mse: 3786136791.785623

# %%
x_test_sorted
# Out:
# array([  398969.        ,   666803.56470588,   934638.12941176,
#         1202472.69411765,  1470307.25882353,  1738141.82352941,
#         2005976.38823529,  2273810.95294118,  2541645.51764706,
#         2809480.08235294,  3077314.64705882,  3345149.21176471,
#         3612983.77647059,  3880818.34117647,  4148652.90588235,
#         4416487.47058824,  4684322.03529412,  4952156.6       ,
#         5219991.16470588,  5487825.72941176,  5755660.29411765,
#         6023494.85882353,  6291329.42352941,  6559163.98823529,
#         6826998.55294118,  7094833.11764706,  7362667.68235294,
#         7630502.24705882,  7898336.81176471,  8166171.37647059,
#         8434005.94117647,  8701840.50588235,  8969675.07058823,
#         9237509.63529412,  9505344.2       ,  9773178.76470588,
#        10041013.32941176, 10308847.89411765, 10576682.45882353,
#        10844517.02352941, 11112351.58823529, 11380186.15294118,
#        11648020.71764706, 11915855.28235294, 12183689.84705882,
# ...

# %%
#Preliminary plotting
predictor = 'TotalNumJobs'
# x_test_sorted = X_test.sort_values(by=predictor)
x_test_sorted = np.linspace(X_train.min(), X_train.max(), len(X_train))
y_pred_test_sorted = baseline_linreg.predict(x_test_sorted)

sns.scatterplot(data=imputed,x=X_train[predictor],y=y_train,alpha=0.8)
sns.scatterplot(data=imputed,x=X_test[predictor],y=y_test,alpha=0.8)
plt.plot(x_test_sorted,y_pred_test_sorted,'r',alpha=0.6)
plt.legend(labels=['Train', 'Test', 'Prediction'])
# Out:
# /Users/shunli/micromamba/envs/cs109a/lib/python3.10/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# fig, axs = plt.subplots(7,2,figsize=(12, 25),sharey='all')

# for count,predictor in enumerate(X_train.columns):
# #     x_test_sorted = X_test.sort_values(by=predictor)
#     x_test_sorted = np.linspace(X_train.min(), X_train.max(), len(X_train))
#     y_pred_test_sorted = baseline_linreg.predict(x_test_sorted)

#     plt.subplot(7,2,count+1)
#     sns.scatterplot(data=imputed,x=X_train[predictor],y=y_train,alpha=0.8)
#     sns.scatterplot(data=imputed,x=X_test[predictor],y=y_test,alpha=0.8)
#     plt.plot(x_test_sorted,y_pred_test_sorted,'r',alpha=0.6)
#     plt.legend(labels=['Train', 'Test', 'Prediction'])
